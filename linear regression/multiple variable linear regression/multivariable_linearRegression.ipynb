# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
bed_median=df.bedrooms.median()//1
bed_median
# Out:
# np.float64(4.0)

# %%
df.bedrooms=df.bedrooms.fillna(bed_median)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area' , 'bedrooms' , 'age']] , df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000 , 3 , 40]])
# Out:
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
reg.predict([[2500 , 4 , 5]])
# Out:
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %%
# %matplotlib inline
plt.scatter(df.age , df.price , color='red' , marker='+')

# %%
# %matplotlib inline
# plt.scatter(df.age , df.price , color='red' , marker='+')
# plt.plot(df[['area' , 'bedrooms' , 'age']] , reg.predict(df[['area' , 'bedrooms' , 'age']]) , color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x27d586d4a10>,
#  <matplotlib.lines.Line2D at 0x27d586cfc80>,
#  <matplotlib.lines.Line2D at 0x27d586ccc50>]
